# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
pd.set_option('max_colwidth', 100)
plt.rcParams.update({'font.size': 24})

# %%
import os

# %% [markdown]
# For models
#
# GRU_2.0_augmentations_allcodeTrue
#
#
# SIG_2.3_logsigTrue_sigdepth2_leadlagTrue_addtime_True_timestampsTrue_allcodeTrue_trainprop1_eval

# %%
os.listdir(data_path)
# Out:
# ['run-SIG_aa023549-bb04-4040-9129-b035c04ccba5_0_log_validation-tag-loss.csv',
#  'run-GRU_40f14540-6c76-4a10-82e7-682fc458c775_0_log_train-tag-auc.csv',
#  'run-SIG_aa023549-bb04-4040-9129-b035c04ccba5_0_log_train-tag-loss.csv',
#  '.DS_Store',
#  'run-SIG_2dd477d0-4a7a-4821-b877-ec735dc6536f_0_log_validation-tag-auc.csv',
#  'run-SIG_2dd477d0-4a7a-4821-b877-ec735dc6536f_0_log_train-tag-auc.csv',
#  'run-GRU_40f14540-6c76-4a10-82e7-682fc458c775_0_log_train-tag-loss.csv',
#  'run-GRU_40f14540-6c76-4a10-82e7-682fc458c775_0_log_validation-tag-average_precision.csv',
#  'run-SIG_aa023549-bb04-4040-9129-b035c04ccba5_0_log_validation-tag-average_precision.csv',
#  'run-GRU_40f14540-6c76-4a10-82e7-682fc458c775_0_log_train-tag-average_precision.csv',
#  'run-SIG_aa023549-bb04-4040-9129-b035c04ccba5_0_log_validation-tag-auc.csv',
#  'run-GRU_40f14540-6c76-4a10-82e7-682fc458c775_0_log_validation-tag-loss.csv',
# ...

# %% [markdown]
# 8ec39cb9-1e27-47ba-95a3-a5c8183a19bb  - SIG LS + LL + ATI

# %%
{ "_id" : 4951, "experiment" : { "name" : "SIG", "base_dir" : "/home/vauvelle/doctor_signature/experiments", "sources" : [ [ "SIG.py", ObjectId("5f47b78d8225c77241fc2cfc") ], [ "__init__.py", ObjectId("5f2d31fb3ddc787e72a2214d") ] ], "dependencies" : [ "allennlp==1.0.0", "numpy==1.18.5", "pandas==1.0.4", "sacred==0.8.1", "torch==1.5.1" ], "repositories" : [ { "url" : "https://github.com/andre-vauvelle/doctor_signature.git", "commit" : "9628e456b9087fb06c597e330749c3d96d135511", "dirty" : true }, { "url" : "https://github.com/andre-vauvelle/doctor_signature.git", "commit" : "9628e456b9087fb06c597e330749c3d96d135511", "dirty" : true } ], "mainfile" : "SIG.py" }, "format" : "MongoObserver-0.7.0", "command" : "main", "host" : { "hostname" : "gonzo-605-3.local", "os" : [ "Linux", "Linux-3.10.0-1127.18.2.el7.x86_64-x86_64-with-centos-7.8.2003-Core" ], "python_version" : "3.7.0", "cpu" : "Intel(R) Xeon(R) CPU E5-2640 v4 @ 2.40GHz", "gpus" : { "gpus" : [ { "model" : "GeForce GTX 1080 Ti", "total_memory" : 11178, "persistence_mode" : true }, { "model" : "GeForce GTX 1080 Ti", "total_memory" : 11178, "persistence_mode" : true }, { "model" : "GeForce GTX 1080 Ti", "total_memory" : 11178, "persistence_mode" : true }, { "model" : "GeForce GTX 1080 Ti", "total_memory" : 11178, "persistence_mode" : true } ], "driver_version" : "450.51.05" }, "ENV" : {  } }, "start_time" : ISODate("2020-08-27T13:39:25.249Z"), "config" : { "__doc__" : "configation for SIG", "name" : "SIG_2.3_logsigTrue_sigdepth2_leadlagTrue_addtime_True_timestampsTrue_allcodeTrue_trainprop1_410kp", "version" : 2.3, "all_code_types" : true, "d_embedding" : 34, "min_count" : 5, "batch_size" : 128, "verbose" : true, "epochs" : 20, "lr" : 0.0015688591396750059, "wd" : 0.00004880130484012399, "sig_depth" : 2, "logsig" : true, "run_name" : "SIG", "testing_subsample_size" : null, "patience" : 5, "feedforward_num_layers" : 1, "feedforward_hidden_dims" : 80, "feedforward_activations" : "relu", "feedforward_dropout" : 0.2677659426536449, "dataset_path" : null, "embedding_dropout_p" : 0, "split_paths" : false, "add_time" : true, "t_max" : 0.32058641362163165, "t_scale" : 533096.1314897189, "use_timestamps" : true, "leadlag" : true, "training_proportion" : 1, "evaluate_on_test" : true, "tensorboard_log" : false, "seed" : 690620250 }, "meta" : { "command" : "main", "options" : { "--beat-interval" : null, "--capture" : null, "--comment" : null, "--debug" : false, "--enforce_clean" : false, "--file_storage" : null, "--force" : false, "--help" : false, "--loglevel" : null, "--mongo_db" : null, "--name" : null, "--pdb" : false, "--print-config" : false, "--priority" : null, "--queue" : false, "--s3" : null, "--sql" : null, "--tiny_db" : null, "--unobserved" : false } }, "status" : "COMPLETED", "resources" : [ ], "artifacts" : [ ], "info" : {  }, "heartbeat" : ISODate("2020-08-27T13:49:05.727Z"), "result" : { "accuracy" : 0.9016078294302692, "average_precision" : { "py/object" : "numpy.float64", "dtype" : "float64", "value" : 0.29061768866484283 }, "f1" : { "py/object" : "numpy.float64", "dtype" : "float64", "value" : 0.8549572267311385 }, "auc" : { "py/object" : "numpy.float64", "dtype" : "float64", "value" : 0.7262890869635124 }, "gpu_batch_0_memory_MB" : 2447, "gpu_batch_1_memory_MB" : 10893, "gpu_batch_2_memory_MB" : 10893, "gpu_batch_3_memory_MB" : 987, "loss" : 0.2853053371111552 }, "stop_time" : ISODate("2020-08-27T13:49:19.180Z") }

# %% [markdown]
# c5e30400-3a85-488c-9699-05229aa8114d - SIG LS LL ATD 410k GeForce GTX 1080 Ti
# bf1bdf44-9b47-493e-9608-24b4436c6d16 - GRU + ATD 410k
#
# c5e30400-3a85-488c-9699-05229aa8114d|bf1bdf44-9b47-493e-9608-24b4436c6d16

# %%
data_path = '/Users/andre/Documents/UCL/DoctorSignature/data/processed/training_metrics'
data = []
for f in os.listdir(data_path):
    if '.csv' in f:
        df = pd.read_csv(os.path.join(data_path, f))
        df=df[:5]
        df.loc[:, 'filename'] = f
        data.append(df)

# %%
df_metrics = pd.concat(data)

# %%
df_metrics.loc[:, 'metric'] = df_metrics.filename.str.split('-').str[-1].str[:-4]
df_metrics.loc[:, 'model'] = df_metrics.filename.str.split('-').str[1].str[:3]
df_metrics.loc[:, 'type'] = df_metrics.filename.str.split('-').str[-3].str.split('_').str[-1].str.capitalize()
df_metrics.loc[:, 'new'] = df_metrics.filename.str.contains('2dd477d0-4a7a-4821-b877-ec735dc6536f')


df_gru = df_metrics[df_metrics.model == 'GRU']
df_sig = df_metrics[(df_metrics.model == 'SIG') & (~df_metrics.new)]
df_sig_n = df_metrics[(df_metrics.model == 'SIG') & (df_metrics.new)]
df_sig_n.loc[:,'model'] = 'SIG_n'

# %%
df_gru.loc[:, 'relative'] = df_gru.loc[:, 'Wall time'] - df_gru.loc[:, 'Wall time'].min()
df_sig.loc[:, 'relative'] = df_sig.loc[:, 'Wall time'] - df_sig.loc[:, 'Wall time'].min()
#df_sig_n.loc[:, 'relative'] = df_sig_n.loc[:, 'Wall time'] - df_sig_n.loc[:, 'Wall time'].min()

df_metrics_pro = pd.concat([df_gru, df_sig]) #df_sig_n

# %%
# %matplotlib notebook
df_metrics_pro.metric.uniquefig, ax = plt.subplots(figsize=(10,10))
df_plot = df_metrics_pro[df_metrics_pro.metric == 'loss']
for ((m, typ), df_p) in df_plot.groupby(['model', 'type']):
    df_p.plot(x='relative', y='Value', label=m+' '+typ, ax=ax, 
              marker='o' if m == 'SIG' else '^', alpha=0.7,linewidth=3, markersize=10, 
              linestyle='-' if typ == 'Validation' else ':')
    ax.set_xlabel('Relative wall time (seconds)')
    ax.set_ylabel('Loss')
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
df_metrics_pro.metric.uniquefig, ax = plt.subplots(figsize=(10,10))
df_plot = df_metrics_pro[df_metrics_pro.metric == 'auc']
for ((m, typ), df_p) in df_plot.groupby(['model', 'type']):
    df_p.plot(x='relative', y='Value', label=m+' '+typ, ax=ax, 
              marker='o' if m == 'SIG' else '^', alpha=0.7,linewidth=3, markersize=10, 
              linestyle='-' if typ == 'Validation' else ':')
    ax.set_xlabel('Relative wall time (seconds)')
    ax.set_ylabel('AUROC')
# Out:
# <img src="data:image/png;base64,..." width="999.999985098839">

# %%
# %matplotlib notebook
df_metrics_pro.metric.uniquefig, ax = plt.subplots(figsize=(10,10))
df_plot = df_metrics_pro[df_metrics_pro.metric == 'average_precision']
for ((m, typ), df_p) in df_plot.groupby(['model', 'type']):
    df_p.plot(x='relative', y='Value', label=m+' '+typ, ax=ax, 
              marker='o' if m == 'SIG' else '^', alpha=0.7,linewidth=3, markersize=10, 
              linestyle='-' if typ == 'Validation' else ':')
    ax.set_xlabel('Relative wall time (seconds)')
    ax.set_ylabel('AUPRC')
# Out:
# <img src="data:image/png;base64,..." width="1000">
